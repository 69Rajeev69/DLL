# %% [markdown]
# 1. Design a multilayer deep neural network with a linear input layer, Tanh or ReLU activation for the hidden layers, and sigmoid or SoftMax activation for the output layer.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(10, activation = 'softmax')
])

model.compile(optimizer = tf.keras.optimizers.Adam(1e-3), loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])

# %%
history = model.fit(train_images, train_labels, batch_size = 64, epochs = 5, validation_data=(test_images, test_labels), verbose = 0)
plt.plot(history.history['loss'], label = "Training Loss")
plt.plot(history.history['val_loss'], label = "Validation Loss")
plt.title("Loss curve")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
x = np.linspace(-5, 5, 100)
plt.plot(x, tf.keras.activations.relu(x))
plt.xlabel("X")
plt.ylabel("Y")
plt.title("ReLU")
plt.show()

x = np.linspace(-5, 5, 1000)
plt.plot(x, tf.keras.activations.sigmoid(x))
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Softmax")
plt.show()
