# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers
import matplotlib.pyplot as plt
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

model = tf.keras.Sequential([
    layers.Lambda(lambda x: tf.expand_dims(x, axis=-1)),
    layers.Conv2D(32, 3, activation="relu"),
    layers.MaxPool2D(),
    layers.Conv2D(32, 3, activation="relu"),
    layers.Flatten(),
    layers.Dense(10, activation="softmax")
])

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])
history = model.fit(x=tf.cast(train_images, tf.float32),
          y=train_labels,
          epochs=10,
          validation_data=(tf.cast(test_images, tf.float32), test_labels))
plt.plot(history.history['loss'], label = "Training Loss")
plt.plot(history.history['val_loss'], label = "Validation Loss")
plt.plot(history.history['accuracy'], label = "Training Accuracy")
plt.plot(history.history['val_accuracy'], label = "Validation Accuracy")
plt.title("Training and validation curve")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1875/1875 [==============================] - 20s 6ms/step - loss: 0.2578 - accuracy: 0.9499 - val_loss: 0.0827 - val_accuracy: 0.9744
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0676 - accuracy: 0.9797 - val_loss: 0.0591 - val_accuracy: 0.9817
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0519 - accuracy: 0.9842 - val_loss: 0.0581 - val_accuracy: 0.9834
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0432 - accuracy: 0.9868 - val_loss: 0.0682 - val_accuracy: 0.9800
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0383 - accuracy: 0.9884 - val_loss: 0.0807 - val_accuracy: 0.9809
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0312 - accuracy: 0.9907 - val_loss: 0.0643 - val_accuracy: 0.9833
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0305 - accuracy: 0.9912 - val_loss: 0.0958 - val_accuracy: 0.9795
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0238 - accuracy: 0.9932 - val_loss: 0.1060 - val_accuracy: 0.9794
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0254 - accuracy: 0.9927 - val_loss: 0.0761 - val_accuracy: 0.9859
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0237 - accuracy: 0.9935 - val_loss: 0.0942 - val_accuracy: 0.9837
